# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import _pickle as cPickle

a = cPickle.load(open('results/sine_task_n_syn_100_g_factor_100_cycle_dur_100_g_S_0.0_alpha_-55.0_beta_0.25_r_max_0.35.p', 'rb'))

# %%
res = a[1][0].res

# %%
res.keys()
# Out:
# dict_keys(['g_E_Ds', 'syn_pots_sums', 'y', 'spike', 'dendr_pred', 'h', 'PIVs', 'pos_PIVs', 'neg_PIVs', 'dendr_spike', 'pre_spikes', 'weights', 'weight_updates', 'deltas', 'I_ext', 'seed'])

# %%
plt.plot(res["g_E_Ds"][:,1][-200:])
plt.show()

# %%
plt.plot(res["syn_pots_sums"][:,1][-200:])
plt.show()

# %%
plt.plot(res["spike"])
plt.show()

# %%
plt.plot(res["dendr_pred"]) # (1700, 100)
plt.show()

# %%
plt.plot(res["dendr_pred"][-100:,:]) # (1700, 100)
plt.show()

# %%
plt.plot(res["dendr_spike"][-100:]) # (1700,)
plt.show()

# %%
plt.plot(res["g_E_Ds"][:,99])
plt.show()

# %%
plt.plot(res["y"][:,0][-200:]) # U
plt.plot(res["y"][:,1][-200:]) # V
plt.plot(res["y"][:,2][-200:]) # V_w_star
plt.show()

# %%
plt.plot(res["y"][:,5][-200:]) 
plt.plot(res["y"][:,6][-200:])
plt.show()

# %%
res["g_E_Ds"].shape
# Out:
# (1700, 100)

# %%
plt.plot(res['neg_PIVs'][:,99])
plt.show()

# %%
plt.plot(res['h'][-200:])
plt.show()

# %%
plt.plot(res['y'][-200:])
plt.show()
