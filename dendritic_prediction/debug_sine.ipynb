# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import _pickle as cPickle

a = cPickle.load(open('results/sine_task_n_syn_100_g_factor_100_cycle_dur_100_g_S_0.0_alpha_-55.0_beta_0.25_r_max_0.35.p', 'rb'))

# %%
res = a[1][0].res

# %%
plt.plot(res["g_E_Ds"][:,99])
plt.show()

# %%
#(1700, 203)
plt.plot(res["y"][:,0][-200:])
plt.show()

# %%
res["g_E_Ds"].shape
# Out:
# (1700, 100)

# %%
plt.plot(res['neg_PIVs'][:,99])
plt.show()

# %%
plt.plot(res['h'][-200:])
plt.show()

# %%
plt.plot(res['y'][-200:])
plt.show()

# %%
res
# Out:
# {'g_E_Ds': array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         ...,
#         [0.0000000e+00, 9.7562297e-06, 7.1425499e-13, ..., 0.0000000e+00,
#          5.0516338e-09, 9.5699776e-05],
#         [0.0000000e+00, 4.9809532e-06, 3.6465633e-13, ..., 0.0000000e+00,
#          2.5790650e-09, 4.8858641e-05],
#         [0.0000000e+00, 2.5429797e-06, 1.8617193e-13, ..., 0.0000000e+00,
#          1.3167180e-09, 2.4944329e-05]], dtype=float32),
#  'syn_pots_sums': array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
# ...
