# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import _pickle as cPickle

a = cPickle.load(open('results/sine_task_n_syn_100_g_factor_10_cycle_dur_100_g_S_0.0_alpha_-55.0_beta_0.25_r_max_0.35.p', 'rb'))

# %%
res = a[1][0].res

# %%
plt.plot(res["g_E_Ds"][:,99])
plt.show()

# %%
#(1700, 203)
plt.plot(res["y"][:,99])
plt.show()

# %%
res["g_E_Ds"].shape
# Out:
# (1700, 100)

# %%
plt.plot(res['neg_PIVs'][:,99])
plt.show()

# %%
plt.plot(res['h'][-200:])
plt.show()

# %%
plt.plot(res['y'][-200:])
plt.show()

# %%
res
# Out:
# {'g_E_Ds': array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 3.55352313e-06, 4.46354278e-08, ...,
#          3.49127754e-06, 0.00000000e+00, 1.05975036e-13],
#         [0.00000000e+00, 1.81421854e-06, 2.27882069e-08, ...,
#          1.78243965e-06, 0.00000000e+00, 5.41045785e-14],
#         [0.00000000e+00, 9.26232531e-07, 1.16343095e-08, ...,
#          9.10008168e-07, 0.00000000e+00, 2.76225948e-14]], dtype=float32),
#  'syn_pots_sums': array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
# ...
